# %%
import SimpleITK as sitk
import cv2
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Read mask and segment

# %%
mask = sitk.ReadImage('/content/gdrive/My Drive/GTSophomoreFall/Emory/Intro/mask.image.0010.png')
seg = sitk.ReadImage('/content/gdrive/My Drive/GTSophomoreFall/Emory/Intro/seg.image.0010.png')
sitk.GetArrayFromImage(mask)
sitk.GetArrayFromImage(seg)
# Out:
# array([[25, 25, 25, ..., 25, 25, 25],
#        [25,  0,  0, ..., 25, 25, 25],
#        [25,  0,  0, ..., 25, 25, 25],
#        ...,
#        [25, 25, 25, ...,  0,  0, 25],
#        [25, 25, 25, ...,  0,  0, 25],
#        [25, 25, 25, ...,  0,  0, 25]], dtype=uint16)

# %% [markdown]
# Display mask

# %%
plt.imshow(sitk.GetArrayFromImage(mask), cmap=plt.cm.bone)
plt.show()

# %% [markdown]
# Display segment

# %%
plt.imshow(sitk.GetArrayFromImage(seg), cmap=plt.cm.bone)
plt.show()

# %% [markdown]
# Display overlayed mask and segment

# %%
plt.figure()
plt.imshow(sitk.GetArrayFromImage(seg), 'gray', interpolation='none')
plt.imshow(sitk.GetArrayFromImage(mask), 'gray', interpolation='none', alpha=0.3)
